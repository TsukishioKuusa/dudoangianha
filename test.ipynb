# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import OneHotEncoder
df = pd.read_csv("vietnam_housing_dataset.csv")

# %%
non_numeric_cols = df.select_dtypes(exclude=[np.number]).columns
df[non_numeric_cols] = df[non_numeric_cols].fillna("Unknown")

# %%
num_cols = df.select_dtypes(include=['int64','float64']).columns
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())
cat_cols = ['Furniture state', 'Legal status', 'Address']
df[cat_cols] = df[cat_cols].fillna("Unknown")

# %%
df_encoded = pd.get_dummies(df, columns=['Legal status'], drop_first=True)

# %%
def extract_address_info(address):
    parts = [p.strip() for p in str(address).split(',')]
    city = parts[-1].rstrip('.') if len(parts) > 0 else "Unknown"
    district = parts[-2] if len(parts) > 1 else "Unknown"
    is_project = 1 if "Dự án" in str(address) else 0
    return city, district, is_project

df['City'], df['District'], df['Is_Project'] = zip(*df['Address'].apply(extract_address_info))

# %%
cols_to_encode = ['City', 'District', 'Legal status']

df_encoded = pd.get_dummies(df, columns=cols_to_encode, drop_first=True)
        
print(df_encoded)
# Out:
#                                                  Address  Area  Frontage  \
# 0      Dự án The Empire - Vinhomes Ocean Park 2, Xã L...  84.0       4.5
# 1      Dự án The Crown - Vinhomes Ocean Park 3, Xã Ng...  60.0       4.5
# 2      Dự án The Crown - Vinhomes Ocean Park 3, Xã Ng...  90.0       6.0
# 3      Đường Nguyễn Văn Khối, Phường 11, Gò Vấp, Hồ C...  54.0       4.5
# 4       Đường Quang Trung, Phường 8, Gò Vấp, Hồ Chí Minh  92.0       4.5
# ...                                                  ...   ...       ...
# 30224  Đường Lê Quang Định, Phường 1, Gò Vấp, Hồ Chí ...  67.0       4.1
# 30225  Đường Ngô Gia Tự, Phường Đức Giang, Long Biên,...  30.0       4.5
# 30226  Đường Gò Dưa, Phường Tam Bình, Thủ Đức, Hồ Chí...  69.4       4.0
# 30227  Đường Quang Trung, Phường 11, Gò Vấp, Hồ Chí Minh  96.0       4.5
# 30228  Đường Đại lộ Thăng Long, Xã An Khánh, Hoài Đức...  35.0       4.5
#
#        Access Road House direction Balcony direction  Floors  Bedrooms  \
# 0              6.0         Unknown           Unknown     4.0       3.0
# 1              6.0         Unknown           Unknown     5.0       3.0
# 2             13.0      Đông - Bắc        Đông - Bắc     5.0       3.0
# 3              3.5       Tây - Nam         Tây - Nam     2.0       2.0
# 4              6.0      Đông - Nam        Đông - Nam     2.0       4.0
# ...            ...             ...               ...     ...       ...
# 30224         16.0         Unknown           Unknown     1.0       3.0
# 30225          6.0         Unknown           Unknown     5.0       3.0
# 30226         15.0      Đông - Bắc        Đông - Bắc     3.0       3.0
# 30227          8.0         Unknown           Unknown     4.0       3.0
# 30228          6.0      Đông - Nam        Đông - Nam     5.0       3.0
#
#        Bathrooms Furniture state  ...  District_Đất Đỏ  District_Định Quán  \
# 0            3.0         Unknown  ...            False               False
# 1            3.0         Unknown  ...            False               False
# 2            3.0         Unknown  ...            False               False
# 3            3.0            Full  ...            False               False
# 4            4.0            Full  ...            False               False
# ...          ...             ...  ...              ...                 ...
# 30224        2.0         Unknown  ...            False               False
# 30225        3.0         Unknown  ...            False               False
# 30226        3.0           Basic  ...            False               False
# 30227        3.0         Unknown  ...            False               False
# 30228        4.0           Basic  ...            False               False
#
#        District_Đống Đa  District_Đồ Sơn  District_Đồng Xoài  \
# 0                 False            False               False
# 1                 False            False               False
# 2                 False            False               False
# 3                 False            False               False
# 4                 False            False               False
# ...                 ...              ...                 ...
# 30224             False            False               False
# 30225             False            False               False
# 30226             False            False               False
# 30227             False            False               False
# 30228             False            False               False
#
#        District_Đức Hòa  District_Đức Trọng  District_Ứng Hòa  \
# 0                 False               False             False
# 1                 False               False             False
# 2                 False               False             False
# 3                 False               False             False
# 4                 False               False             False
# ...                 ...                 ...               ...
# 30224             False               False             False
# 30225             False               False             False
# 30226             False               False             False
# 30227             False               False             False
# 30228             False               False             False
#
#        Legal status_Sale contract  Legal status_Unknown
# 0                           False                 False
# 1                           False                  True
# 2                            True                 False
# 3                           False                 False
# 4                           False                 False
# ...                           ...                   ...
# 30224                       False                 False
# 30225                       False                 False
# 30226                       False                 False
# 30227                       False                  True
# 30228                       False                 False
#
# [30229 rows x 432 columns]

# %%
import matplotlib.pyplot as mp
import pandas as pd

data = {'Ho va ten': }
# Out:
# hello wworld
